# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from level2 import CustomFrozenLakeEnv

# Set your environment name
environment_name = 'FrozenLake-v1'
render_mode = 'human'

# Create a custom FrozenLake environment
custom_lake = CustomFrozenLakeEnv(size=8, num_holes=8, start_point=(0, 0), end_point=(7, 7))

# ------------------------------------------------------------------------------------------
# training on random board that has been generated


from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
import os
import time

# ... (unchanged CustomFrozenLakeEnv definition)

# # Create the environment
env = custom_lake
env = DummyVecEnv([lambda: env])  # Wrap the environment for compatibility

# # Create the PPO agent
ppo_agent = PPO("MlpPolicy", env, verbose=1)

# # Number of training steps
num_steps = 1000000

# # Train the agent
ppo_agent.learn(total_timesteps=num_steps)

# # Save the trained model
model_save_path = "/Users/software/Desktop/reinforcement_learning_practise/hackathon/"
os.makedirs(model_save_path, exist_ok=True)
location = os.path.join(model_save_path, "level2_custom_frozenlake_model")
ppo_agent.save(location)




# ------------------------------------------------------------------------------------------


# trial runs
# Out:
# /Users/software/anaconda3/envs/mlp/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cpu device
# -----------------------------
# | time/              |      |
# |    fps             | 7153 |
# |    iterations      | 1    |
# |    time_elapsed    | 0    |
# |    total_timesteps | 2048 |
# -----------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4557        |
# |    iterations           | 2           |
# |    time_elapsed         | 0           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.016015537 |
# |    clip_fraction        | 0.0958      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.38       |
# |    explained_variance   | -31         |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00947    |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0121     |
# |    value_loss           | 0.00893     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 4064        |
# |    iterations           | 3           |
# |    time_elapsed         | 1           |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009404974 |
# |    clip_fraction        | 0.0393      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.37       |
# |    explained_variance   | -15.6       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0217     |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0119     |
# |    value_loss           | 0.000421    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3863        |
# |    iterations           | 4           |
# |    time_elapsed         | 2           |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.008027984 |
# |    clip_fraction        | 0.0479      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.34       |
# |    explained_variance   | -15.1       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00456     |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 6.55e-05    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3747       |
# |    iterations           | 5          |
# |    time_elapsed         | 2          |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01482709 |
# |    clip_fraction        | 0.135      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.3       |
# |    explained_variance   | -4.24      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0414    |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0203    |
# |    value_loss           | 3.32e-06   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3688         |
# |    iterations           | 6            |
# |    time_elapsed         | 3            |
# |    total_timesteps      | 12288        |
# | train/                  |              |
# |    approx_kl            | 0.0072956407 |
# |    clip_fraction        | 0.0654       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.28        |
# |    explained_variance   | -0.824       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0374       |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0109      |
# |    value_loss           | 0.00372      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3640        |
# |    iterations           | 7           |
# |    time_elapsed         | 3           |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.011952432 |
# |    clip_fraction        | 0.113       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.25       |
# |    explained_variance   | 0.128       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0407     |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.0104      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3607        |
# |    iterations           | 8           |
# |    time_elapsed         | 4           |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.015639067 |
# |    clip_fraction        | 0.216       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.19       |
# |    explained_variance   | 0.346       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0353     |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0339     |
# |    value_loss           | 0.0263      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3582       |
# |    iterations           | 9          |
# |    time_elapsed         | 5          |
# |    total_timesteps      | 18432      |
# | train/                  |            |
# |    approx_kl            | 0.01618592 |
# |    clip_fraction        | 0.251      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -1.11      |
# |    explained_variance   | 0.429      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0127     |
# |    n_updates            | 80         |
# |    policy_gradient_loss | -0.0386    |
# |    value_loss           | 0.0544     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3561        |
# |    iterations           | 10          |
# |    time_elapsed         | 5           |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.015559876 |
# |    clip_fraction        | 0.189       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.03       |
# |    explained_variance   | 0.375       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00752    |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.032      |
# |    value_loss           | 0.0706      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3543        |
# |    iterations           | 11          |
# |    time_elapsed         | 6           |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.019837135 |
# |    clip_fraction        | 0.222       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.894      |
# |    explained_variance   | 0.353       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0106     |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0317     |
# |    value_loss           | 0.0442      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3528       |
# |    iterations           | 12         |
# |    time_elapsed         | 6          |
# |    total_timesteps      | 24576      |
# | train/                  |            |
# |    approx_kl            | 0.01037719 |
# |    clip_fraction        | 0.118      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.798     |
# |    explained_variance   | 0.178      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0316    |
# |    n_updates            | 110        |
# |    policy_gradient_loss | -0.0209    |
# |    value_loss           | 0.0248     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3517        |
# |    iterations           | 13          |
# |    time_elapsed         | 7           |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.011167403 |
# |    clip_fraction        | 0.125       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.703      |
# |    explained_variance   | 0.162       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00504    |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 0.0331      |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3508       |
# |    iterations           | 14         |
# |    time_elapsed         | 8          |
# |    total_timesteps      | 28672      |
# | train/                  |            |
# |    approx_kl            | 0.01407595 |
# |    clip_fraction        | 0.156      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.598     |
# |    explained_variance   | 0.128      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0299    |
# |    n_updates            | 130        |
# |    policy_gradient_loss | -0.0199    |
# |    value_loss           | 0.0303     |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3499        |
# |    iterations           | 15          |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.013716657 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.508      |
# |    explained_variance   | 0.293       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00541    |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0154     |
# |    value_loss           | 0.00886     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3493        |
# |    iterations           | 16          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.015732266 |
# |    clip_fraction        | 0.0709      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.392      |
# |    explained_variance   | 0.347       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00831    |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0159     |
# |    value_loss           | 0.00381     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3488        |
# |    iterations           | 17          |
# |    time_elapsed         | 9           |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.016399007 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.338      |
# |    explained_variance   | 0.877       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00229    |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.013      |
# |    value_loss           | 7.04e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3482        |
# |    iterations           | 18          |
# |    time_elapsed         | 10          |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.016549882 |
# |    clip_fraction        | 0.0677      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.255      |
# |    explained_variance   | 0.319       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0295     |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0149     |
# |    value_loss           | 0.00391     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3478         |
# |    iterations           | 19           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0053554904 |
# |    clip_fraction        | 0.0462       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.199       |
# |    explained_variance   | 0.939        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00499     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.0088      |
# |    value_loss           | 4.88e-05     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3476         |
# |    iterations           | 20           |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0029565906 |
# |    clip_fraction        | 0.033        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.176       |
# |    explained_variance   | 0.99         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0102      |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.00735     |
# |    value_loss           | 1.26e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3473        |
# |    iterations           | 21          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.002274563 |
# |    clip_fraction        | 0.0215      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.162      |
# |    explained_variance   | 0.243       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00734     |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00479    |
# |    value_loss           | 0.00533     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3469        |
# |    iterations           | 22          |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.007830498 |
# |    clip_fraction        | 0.0585      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.176      |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0342     |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.00706    |
# |    value_loss           | 0.00262     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3466         |
# |    iterations           | 23           |
# |    time_elapsed         | 13           |
# |    total_timesteps      | 47104        |
# | train/                  |              |
# |    approx_kl            | 0.0044917976 |
# |    clip_fraction        | 0.0272       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.181       |
# |    explained_variance   | 0.923        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0179       |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.00511     |
# |    value_loss           | 1.5e-05      |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3463        |
# |    iterations           | 24          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.016803935 |
# |    clip_fraction        | 0.118       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | 0.344       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00438    |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0147     |
# |    value_loss           | 0.00356     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3461        |
# |    iterations           | 25          |
# |    time_elapsed         | 14          |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.009580281 |
# |    clip_fraction        | 0.0469      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.211      |
# |    explained_variance   | 0.333       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0032      |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.00466    |
# |    value_loss           | 0.00322     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3453        |
# |    iterations           | 26          |
# |    time_elapsed         | 15          |
# |    total_timesteps      | 53248       |
# | train/                  |             |
# |    approx_kl            | 0.015007244 |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.223      |
# |    explained_variance   | 0.947       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0244     |
# |    n_updates            | 250         |
# |    policy_gradient_loss | -0.0108     |
# |    value_loss           | 9.63e-06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3451       |
# |    iterations           | 27         |
# |    time_elapsed         | 16         |
# |    total_timesteps      | 55296      |
# | train/                  |            |
# |    approx_kl            | 0.01810002 |
# |    clip_fraction        | 0.151      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.248     |
# |    explained_variance   | 0.964      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0195    |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -0.0241    |
# |    value_loss           | 5.46e-05   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3450        |
# |    iterations           | 28          |
# |    time_elapsed         | 16          |
# |    total_timesteps      | 57344       |
# | train/                  |             |
# |    approx_kl            | 0.028774185 |
# |    clip_fraction        | 0.0773      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.192      |
# |    explained_variance   | 0.985       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0151     |
# |    n_updates            | 270         |
# |    policy_gradient_loss | -0.0223     |
# |    value_loss           | 2.03e-05    |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 3448      |
# |    iterations           | 29        |
# |    time_elapsed         | 17        |
# |    total_timesteps      | 59392     |
# | train/                  |           |
# |    approx_kl            | 0.0134169 |
# |    clip_fraction        | 0.0592    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.181    |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00181   |
# |    n_updates            | 280       |
# |    policy_gradient_loss | -0.0071   |
# |    value_loss           | 3.54e-06  |
# ---------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3446         |
# |    iterations           | 30           |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 61440        |
# | train/                  |              |
# |    approx_kl            | 0.0047626668 |
# |    clip_fraction        | 0.022        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.169       |
# |    explained_variance   | 0.998        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00734     |
# |    n_updates            | 290          |
# |    policy_gradient_loss | -0.00348     |
# |    value_loss           | 2.37e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3445        |
# |    iterations           | 31          |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 63488       |
# | train/                  |             |
# |    approx_kl            | 0.001490698 |
# |    clip_fraction        | 0.0201      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.185      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00222    |
# |    n_updates            | 300         |
# |    policy_gradient_loss | -0.00496    |
# |    value_loss           | 3e-06       |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3443        |
# |    iterations           | 32          |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 65536       |
# | train/                  |             |
# |    approx_kl            | 0.005899596 |
# |    clip_fraction        | 0.0865      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.192      |
# |    explained_variance   | 0.176       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0178     |
# |    n_updates            | 310         |
# |    policy_gradient_loss | -0.00984    |
# |    value_loss           | 0.00823     |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 3442      |
# |    iterations           | 33        |
# |    time_elapsed         | 19        |
# |    total_timesteps      | 67584     |
# | train/                  |           |
# |    approx_kl            | 0.0095092 |
# |    clip_fraction        | 0.0377    |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.167    |
# |    explained_variance   | 0.22      |
# |    learning_rate        | 0.0003    |
# |    loss                 | -0.00129  |
# |    n_updates            | 320       |
# |    policy_gradient_loss | -0.00893  |
# |    value_loss           | 0.00767   |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3441        |
# |    iterations           | 34          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 69632       |
# | train/                  |             |
# |    approx_kl            | 0.014681411 |
# |    clip_fraction        | 0.0508      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.194      |
# |    explained_variance   | 0.953       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0459     |
# |    n_updates            | 330         |
# |    policy_gradient_loss | -0.00985    |
# |    value_loss           | 2.35e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3440        |
# |    iterations           | 35          |
# |    time_elapsed         | 20          |
# |    total_timesteps      | 71680       |
# | train/                  |             |
# |    approx_kl            | 0.005701231 |
# |    clip_fraction        | 0.0389      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.226      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00381    |
# |    n_updates            | 340         |
# |    policy_gradient_loss | -0.00534    |
# |    value_loss           | 3.31e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3439         |
# |    iterations           | 36           |
# |    time_elapsed         | 21           |
# |    total_timesteps      | 73728        |
# | train/                  |              |
# |    approx_kl            | 0.0046439087 |
# |    clip_fraction        | 0.0717       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.238       |
# |    explained_variance   | 0.986        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0229      |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0142      |
# |    value_loss           | 1.93e-05     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3438        |
# |    iterations           | 37          |
# |    time_elapsed         | 22          |
# |    total_timesteps      | 75776       |
# | train/                  |             |
# |    approx_kl            | 0.008035861 |
# |    clip_fraction        | 0.0672      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.222      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00152     |
# |    n_updates            | 360         |
# |    policy_gradient_loss | -0.00956    |
# |    value_loss           | 1.14e-05    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3437         |
# |    iterations           | 38           |
# |    time_elapsed         | 22           |
# |    total_timesteps      | 77824        |
# | train/                  |              |
# |    approx_kl            | 0.0052020615 |
# |    clip_fraction        | 0.0624       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00168     |
# |    n_updates            | 370          |
# |    policy_gradient_loss | -0.00569     |
# |    value_loss           | 3.65e-06     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3437       |
# |    iterations           | 39         |
# |    time_elapsed         | 23         |
# |    total_timesteps      | 79872      |
# | train/                  |            |
# |    approx_kl            | 0.00750236 |
# |    clip_fraction        | 0.07       |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.207     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.00327   |
# |    n_updates            | 380        |
# |    policy_gradient_loss | -0.00751   |
# |    value_loss           | 4.85e-06   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3436         |
# |    iterations           | 40           |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0054577095 |
# |    clip_fraction        | 0.0657       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.222       |
# |    explained_variance   | 0.32         |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.003       |
# |    n_updates            | 390          |
# |    policy_gradient_loss | -0.00353     |
# |    value_loss           | 0.00331      |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3435         |
# |    iterations           | 41           |
# |    time_elapsed         | 24           |
# |    total_timesteps      | 83968        |
# | train/                  |              |
# |    approx_kl            | 0.0065490073 |
# |    clip_fraction        | 0.0555       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.225       |
# |    explained_variance   | 0.955        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00646     |
# |    n_updates            | 400          |
# |    policy_gradient_loss | -0.00294     |
# |    value_loss           | 7.81e-06     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3435         |
# |    iterations           | 42           |
# |    time_elapsed         | 25           |
# |    total_timesteps      | 86016        |
# | train/                  |              |
# |    approx_kl            | 0.0060833674 |
# |    clip_fraction        | 0.0756       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.213       |
# |    explained_variance   | 0.995        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00356      |
# |    n_updates            | 410          |
# |    policy_gradient_loss | -0.0052      |
# |    value_loss           | 3.77e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3434        |
# |    iterations           | 43          |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 88064       |
# | train/                  |             |
# |    approx_kl            | 0.004478654 |
# |    clip_fraction        | 0.0532      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.189      |
# |    explained_variance   | 0.995       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0274     |
# |    n_updates            | 420         |
# |    policy_gradient_loss | -0.00747    |
# |    value_loss           | 7.44e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3433         |
# |    iterations           | 44           |
# |    time_elapsed         | 26           |
# |    total_timesteps      | 90112        |
# | train/                  |              |
# |    approx_kl            | 0.0078098774 |
# |    clip_fraction        | 0.0283       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.182       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.00761     |
# |    n_updates            | 430          |
# |    policy_gradient_loss | -0.00345     |
# |    value_loss           | 7.34e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3432        |
# |    iterations           | 45          |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 92160       |
# | train/                  |             |
# |    approx_kl            | 0.005960687 |
# |    clip_fraction        | 0.0478      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.191      |
# |    explained_variance   | 0.543       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0127     |
# |    n_updates            | 440         |
# |    policy_gradient_loss | -0.00174    |
# |    value_loss           | 0.00142     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3432        |
# |    iterations           | 46          |
# |    time_elapsed         | 27          |
# |    total_timesteps      | 94208       |
# | train/                  |             |
# |    approx_kl            | 0.006310637 |
# |    clip_fraction        | 0.0361      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.205      |
# |    explained_variance   | 0.951       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.0149      |
# |    n_updates            | 450         |
# |    policy_gradient_loss | -0.0024     |
# |    value_loss           | 6.28e-06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3431       |
# |    iterations           | 47         |
# |    time_elapsed         | 28         |
# |    total_timesteps      | 96256      |
# | train/                  |            |
# |    approx_kl            | 0.01015494 |
# |    clip_fraction        | 0.056      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.236     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.000503   |
# |    n_updates            | 460        |
# |    policy_gradient_loss | -0.00691   |
# |    value_loss           | 2.91e-06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3430        |
# |    iterations           | 48          |
# |    time_elapsed         | 28          |
# |    total_timesteps      | 98304       |
# | train/                  |             |
# |    approx_kl            | 0.011455858 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.248      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00585    |
# |    n_updates            | 470         |
# |    policy_gradient_loss | -0.0112     |
# |    value_loss           | 2.55e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3430        |
# |    iterations           | 49          |
# |    time_elapsed         | 29          |
# |    total_timesteps      | 100352      |
# | train/                  |             |
# |    approx_kl            | 0.008566442 |
# |    clip_fraction        | 0.0891      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.23       |
# |    explained_variance   | 0.396       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.033      |
# |    n_updates            | 480         |
# |    policy_gradient_loss | -0.011      |
# |    value_loss           | 0.00284     |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3430         |
# |    iterations           | 50           |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 102400       |
# | train/                  |              |
# |    approx_kl            | 0.0051667998 |
# |    clip_fraction        | 0.0541       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.243       |
# |    explained_variance   | 0.508        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00733      |
# |    n_updates            | 490          |
# |    policy_gradient_loss | -0.00376     |
# |    value_loss           | 0.0014       |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3430        |
# |    iterations           | 51          |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 104448      |
# | train/                  |             |
# |    approx_kl            | 0.009685879 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.256      |
# |    explained_variance   | 0.956       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00134    |
# |    n_updates            | 500         |
# |    policy_gradient_loss | -0.00472    |
# |    value_loss           | 1.06e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3429        |
# |    iterations           | 52          |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 106496      |
# | train/                  |             |
# |    approx_kl            | 0.012331642 |
# |    clip_fraction        | 0.162       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.268      |
# |    explained_variance   | 0.997       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.027      |
# |    n_updates            | 510         |
# |    policy_gradient_loss | -0.00168    |
# |    value_loss           | 3.18e-06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3428       |
# |    iterations           | 53         |
# |    time_elapsed         | 31         |
# |    total_timesteps      | 108544     |
# | train/                  |            |
# |    approx_kl            | 0.01747316 |
# |    clip_fraction        | 0.136      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.242     |
# |    explained_variance   | 0.979      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0213    |
# |    n_updates            | 520        |
# |    policy_gradient_loss | -0.0196    |
# |    value_loss           | 3.23e-05   |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3428       |
# |    iterations           | 54         |
# |    time_elapsed         | 32         |
# |    total_timesteps      | 110592     |
# | train/                  |            |
# |    approx_kl            | 0.01540002 |
# |    clip_fraction        | 0.0447     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.206     |
# |    explained_variance   | 0.992      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0187    |
# |    n_updates            | 530        |
# |    policy_gradient_loss | -0.0146    |
# |    value_loss           | 1.12e-05   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3428         |
# |    iterations           | 55           |
# |    time_elapsed         | 32           |
# |    total_timesteps      | 112640       |
# | train/                  |              |
# |    approx_kl            | 0.0062497845 |
# |    clip_fraction        | 0.0673       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.189       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.000873     |
# |    n_updates            | 540          |
# |    policy_gradient_loss | -0.00746     |
# |    value_loss           | 1.03e-06     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3427        |
# |    iterations           | 56          |
# |    time_elapsed         | 33          |
# |    total_timesteps      | 114688      |
# | train/                  |             |
# |    approx_kl            | 0.008653374 |
# |    clip_fraction        | 0.06        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.214      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0242     |
# |    n_updates            | 550         |
# |    policy_gradient_loss | -0.00531    |
# |    value_loss           | 1.49e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3427         |
# |    iterations           | 57           |
# |    time_elapsed         | 34           |
# |    total_timesteps      | 116736       |
# | train/                  |              |
# |    approx_kl            | 0.0038000776 |
# |    clip_fraction        | 0.0354       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.216       |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -3.95e-05    |
# |    n_updates            | 560          |
# |    policy_gradient_loss | -0.00269     |
# |    value_loss           | 3.76e-07     |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3427        |
# |    iterations           | 58          |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 118784      |
# | train/                  |             |
# |    approx_kl            | 0.012654267 |
# |    clip_fraction        | 0.0616      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.225      |
# |    explained_variance   | 0.999       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00785     |
# |    n_updates            | 570         |
# |    policy_gradient_loss | -0.00617    |
# |    value_loss           | 8.24e-07    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3427         |
# |    iterations           | 59           |
# |    time_elapsed         | 35           |
# |    total_timesteps      | 120832       |
# | train/                  |              |
# |    approx_kl            | 0.0050686933 |
# |    clip_fraction        | 0.0593       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.218       |
# |    explained_variance   | 0.999        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0206      |
# |    n_updates            | 580          |
# |    policy_gradient_loss | -0.00819     |
# |    value_loss           | 1.07e-06     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3426       |
# |    iterations           | 60         |
# |    time_elapsed         | 35         |
# |    total_timesteps      | 122880     |
# | train/                  |            |
# |    approx_kl            | 0.00527115 |
# |    clip_fraction        | 0.0362     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.223     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0179    |
# |    n_updates            | 590        |
# |    policy_gradient_loss | -0.00454   |
# |    value_loss           | 4.66e-06   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3426        |
# |    iterations           | 61          |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 124928      |
# | train/                  |             |
# |    approx_kl            | 0.009565748 |
# |    clip_fraction        | 0.0831      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0185     |
# |    n_updates            | 600         |
# |    policy_gradient_loss | -0.00417    |
# |    value_loss           | 2.44e-06    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3426        |
# |    iterations           | 62          |
# |    time_elapsed         | 37          |
# |    total_timesteps      | 126976      |
# | train/                  |             |
# |    approx_kl            | 0.011491938 |
# |    clip_fraction        | 0.0713      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.243      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00577    |
# |    n_updates            | 610         |
# |    policy_gradient_loss | -0.00902    |
# |    value_loss           | 2.8e-06     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3426       |
# |    iterations           | 63         |
# |    time_elapsed         | 37         |
# |    total_timesteps      | 129024     |
# | train/                  |            |
# |    approx_kl            | 0.01841848 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.276     |
# |    explained_variance   | 0.999      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0257    |
# |    n_updates            | 620        |
# |    policy_gradient_loss | -0.0106    |
# |    value_loss           | 9.82e-07   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3426        |
# |    iterations           | 64          |
# |    time_elapsed         | 38          |
# |    total_timesteps      | 131072      |
# | train/                  |             |
# |    approx_kl            | 0.009348364 |
# |    clip_fraction        | 0.0956      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.294      |
# |    explained_variance   | 0.999       |
# ...
# |    n_updates            | 4670        |
# |    policy_gradient_loss | -0.0173     |
# |    value_loss           | 3.6e-06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3375        |
# |    iterations           | 469         |
# |    time_elapsed         | 284         |
# |    total_timesteps      | 960512      |
# | train/                  |             |
# |    approx_kl            | 0.036679756 |
# |    clip_fraction        | 0.153       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.237      |
# |    explained_variance   | 0.946       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.018      |
# |    n_updates            | 4680        |
# |    policy_gradient_loss | -0.0256     |
# |    value_loss           | 8.18e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3375        |
# |    iterations           | 470         |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 962560      |
# | train/                  |             |
# |    approx_kl            | 0.030716054 |
# |    clip_fraction        | 0.0698      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.197      |
# |    explained_variance   | 0.991       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00449    |
# |    n_updates            | 4690        |
# |    policy_gradient_loss | -0.0133     |
# |    value_loss           | 9.7e-06     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 471         |
# |    time_elapsed         | 285         |
# |    total_timesteps      | 964608      |
# | train/                  |             |
# |    approx_kl            | 0.004545286 |
# |    clip_fraction        | 0.0949      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.209      |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00915    |
# |    n_updates            | 4700        |
# |    policy_gradient_loss | -0.0109     |
# |    value_loss           | 0.00254     |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 472         |
# |    time_elapsed         | 286         |
# |    total_timesteps      | 966656      |
# | train/                  |             |
# |    approx_kl            | 0.008604217 |
# |    clip_fraction        | 0.0275      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.181      |
# |    explained_variance   | 0.759       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00689    |
# |    n_updates            | 4710        |
# |    policy_gradient_loss | -0.00644    |
# |    value_loss           | 0.000117    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3376       |
# |    iterations           | 473        |
# |    time_elapsed         | 286        |
# |    total_timesteps      | 968704     |
# | train/                  |            |
# |    approx_kl            | 0.03388855 |
# |    clip_fraction        | 0.127      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.202     |
# |    explained_variance   | 0.954      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0119    |
# |    n_updates            | 4720       |
# |    policy_gradient_loss | -0.0226    |
# |    value_loss           | 6.6e-05    |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 474         |
# |    time_elapsed         | 287         |
# |    total_timesteps      | 970752      |
# | train/                  |             |
# |    approx_kl            | 0.027044479 |
# |    clip_fraction        | 0.0395      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.156      |
# |    explained_variance   | 0.992       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0436     |
# |    n_updates            | 4730        |
# |    policy_gradient_loss | -0.02       |
# |    value_loss           | 7.49e-06    |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3376         |
# |    iterations           | 475          |
# |    time_elapsed         | 288          |
# |    total_timesteps      | 972800       |
# | train/                  |              |
# |    approx_kl            | 0.0037728306 |
# |    clip_fraction        | 0.0419       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.154       |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.012       |
# |    n_updates            | 4740         |
# |    policy_gradient_loss | -0.00759     |
# |    value_loss           | 8.89e-08     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3376       |
# |    iterations           | 476        |
# |    time_elapsed         | 288        |
# |    total_timesteps      | 974848     |
# | train/                  |            |
# |    approx_kl            | 0.01036373 |
# |    clip_fraction        | 0.112      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.188     |
# |    explained_variance   | 0.997      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0287    |
# |    n_updates            | 4750       |
# |    policy_gradient_loss | -0.0102    |
# |    value_loss           | 4.11e-06   |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 3376         |
# |    iterations           | 477          |
# |    time_elapsed         | 289          |
# |    total_timesteps      | 976896       |
# | train/                  |              |
# |    approx_kl            | 0.0099142315 |
# |    clip_fraction        | 0.0948       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.18        |
# |    explained_variance   | 0.997        |
# |    learning_rate        | 0.0003       |
# |    loss                 | -0.0171      |
# |    n_updates            | 4760         |
# |    policy_gradient_loss | -0.0131      |
# |    value_loss           | 3.98e-06     |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3375       |
# |    iterations           | 478        |
# |    time_elapsed         | 289        |
# |    total_timesteps      | 978944     |
# | train/                  |            |
# |    approx_kl            | 0.01457135 |
# |    clip_fraction        | 0.075      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.183     |
# |    explained_variance   | 1          |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0219    |
# |    n_updates            | 4770       |
# |    policy_gradient_loss | -0.00942   |
# |    value_loss           | 1.98e-08   |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3375        |
# |    iterations           | 479         |
# |    time_elapsed         | 290         |
# |    total_timesteps      | 980992      |
# | train/                  |             |
# |    approx_kl            | 0.015194961 |
# |    clip_fraction        | 0.142       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.198      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0543     |
# |    n_updates            | 4780        |
# |    policy_gradient_loss | -0.0299     |
# |    value_loss           | 5.47e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3375        |
# |    iterations           | 480         |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 983040      |
# | train/                  |             |
# |    approx_kl            | 0.006209363 |
# |    clip_fraction        | 0.102       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.167      |
# |    explained_variance   | 0.989       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0428     |
# |    n_updates            | 4790        |
# |    policy_gradient_loss | -0.0219     |
# |    value_loss           | 1.37e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3375        |
# |    iterations           | 481         |
# |    time_elapsed         | 291         |
# |    total_timesteps      | 985088      |
# | train/                  |             |
# |    approx_kl            | 0.028916853 |
# |    clip_fraction        | 0.105       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.154      |
# |    explained_variance   | 0.998       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0298     |
# |    n_updates            | 4800        |
# |    policy_gradient_loss | -0.0191     |
# |    value_loss           | 1.73e-06    |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3375       |
# |    iterations           | 482        |
# |    time_elapsed         | 292        |
# |    total_timesteps      | 987136     |
# | train/                  |            |
# |    approx_kl            | 0.06835382 |
# |    clip_fraction        | 0.172      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.214     |
# |    explained_variance   | 0.045      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.0376     |
# |    n_updates            | 4810       |
# |    policy_gradient_loss | -0.0373    |
# |    value_loss           | 0.106      |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 483         |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 989184      |
# | train/                  |             |
# |    approx_kl            | 0.016617557 |
# |    clip_fraction        | 0.0634      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.251      |
# |    explained_variance   | -0.653      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00178     |
# |    n_updates            | 4820        |
# |    policy_gradient_loss | -0.0146     |
# |    value_loss           | 0.0197      |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 484         |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 991232      |
# | train/                  |             |
# |    approx_kl            | 0.011306539 |
# |    clip_fraction        | 0.0427      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.265      |
# |    explained_variance   | 0.0958      |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0215     |
# |    n_updates            | 4830        |
# |    policy_gradient_loss | -0.00663    |
# |    value_loss           | 0.000286    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 485         |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 993280      |
# | train/                  |             |
# |    approx_kl            | 0.009566335 |
# |    clip_fraction        | 0.158       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.273      |
# |    explained_variance   | 0.86        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0148     |
# |    n_updates            | 4840        |
# |    policy_gradient_loss | -0.0222     |
# |    value_loss           | 0.000133    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 486         |
# |    time_elapsed         | 294         |
# |    total_timesteps      | 995328      |
# | train/                  |             |
# |    approx_kl            | 0.022411987 |
# |    clip_fraction        | 0.16        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.208      |
# |    explained_variance   | 0.962       |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.0236     |
# |    n_updates            | 4850        |
# |    policy_gradient_loss | -0.0314     |
# |    value_loss           | 6.24e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 487         |
# |    time_elapsed         | 295         |
# |    total_timesteps      | 997376      |
# | train/                  |             |
# |    approx_kl            | 0.009384054 |
# |    clip_fraction        | 0.0767      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.159      |
# |    explained_variance   | 0.99        |
# |    learning_rate        | 0.0003      |
# |    loss                 | -0.00798    |
# |    n_updates            | 4860        |
# |    policy_gradient_loss | -0.0176     |
# |    value_loss           | 1.42e-05    |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 3376        |
# |    iterations           | 488         |
# |    time_elapsed         | 296         |
# |    total_timesteps      | 999424      |
# | train/                  |             |
# |    approx_kl            | 0.008159709 |
# |    clip_fraction        | 0.0385      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.157      |
# |    explained_variance   | 0.367       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 0.00233     |
# |    n_updates            | 4870        |
# |    policy_gradient_loss | 0.00235     |
# |    value_loss           | 0.00278     |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 3376       |
# |    iterations           | 489        |
# |    time_elapsed         | 296        |
# |    total_timesteps      | 1001472    |
# | train/                  |            |
# |    approx_kl            | 0.00926974 |
# |    clip_fraction        | 0.107      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.194     |
# |    explained_variance   | 0.983      |
# |    learning_rate        | 0.0003     |
# |    loss                 | -0.0421    |
# |    n_updates            | 4880       |
# |    policy_gradient_loss | -0.0148    |
# |    value_loss           | 1.24e-05   |
# ----------------------------------------

# %%
custom_lake.render()
custom_lake = [''.join(sublist) for sublist in custom_lake.desc]

print(custom_lake)
# Out:
# ['SFFFHFFF', 'FHFFFFFF', 'FFFFFFFF', 'FFFFHFFF', 'FFFFFFFF', 'FFHFFHFF', 'FFFFFHFF', 'HHFFFFFG']

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from level2 import CustomFrozenLakeEnv

environment_name = 'FrozenLake-v1'
render_mode = 'human'

try:
    gym_env = gym.make(environment_name, desc=custom_lake, render_mode=render_mode)
    vec_env = DummyVecEnv([lambda: gym_env])
except gym.error.UnregisteredEnv:
    # If the Gymnasium environment is not available, use the OpenAI Gym environment
    vec_env = DummyVecEnv([lambda: gym.make(environment_name, desc=custom_lake, render_mode=render_mode)])





# Load the trained model
model = PPO.load(location)

# Set the number of episodes for the trial
num_episodes = 50

# Run a trial of various episodes
for episode in range(num_episodes):
    obs = vec_env.reset()
    total_reward = 0
    done = False
    episode_path = {"observations": [], "actions": [], "rewards": []}

    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = vec_env.step(action)

        # Store observations, actions, and rewards during the episode
        episode_path["observations"].append(obs.copy())
        episode_path["actions"].append(action)
        episode_path["rewards"].append(reward)

        total_reward += reward

    print(f"Episode {episode + 1} - Total Reward: {total_reward}")

    # Check if the episode was successful
    if total_reward == 1:
        print("Episode succeeded!")
        print("Observations:", episode_path["observations"])
        print("Actions:", episode_path["actions"])
        print("Rewards:", episode_path["rewards"])

# Close the environment
vec_env.close()
# Out:
# /Users/software/anaconda3/envs/mlp/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Episode 1 - Total Reward: [0.]
# Episode 2 - Total Reward: [0.]
# Episode 3 - Total Reward: [0.]
# Episode 4 - Total Reward: [0.]
# Episode 5 - Total Reward: [0.]
# Episode 6 - Total Reward: [0.]
# Episode 7 - Total Reward: [0.]
# Episode 8 - Total Reward: [0.]
# Episode 9 - Total Reward: [0.]
# Episode 10 - Total Reward: [0.]
# Episode 11 - Total Reward: [0.]
# Episode 12 - Total Reward: [0.]
# Episode 13 - Total Reward: [0.]
# Episode 14 - Total Reward: [0.]
# Episode 15 - Total Reward: [0.]
# Episode 16 - Total Reward: [0.]
# Episode 17 - Total Reward: [0.]
# Episode 18 - Total Reward: [1.]
# Episode succeeded!
# Observations: [array([1]), array([1]), array([2]), array([3]), array([2]), array([3]), array([11]), array([12]), array([13]), array([21]), array([20]), array([21]), array([20]), array([21]), array([22]), array([23]), array([31]), array([30]), array([29]), array([37]), array([38]), array([37]), array([38]), array([46]), array([54]), array([46]), array([54]), array([55]), array([54]), array([55]), array([0])]
# Actions: [array([3]), array([3]), array([3]), array([3]), array([1]), array([3]), array([1]), array([1]), array([1]), array([1]), array([1]), array([3]), array([1]), array([3]), array([1]), array([1]), array([1]), array([1]), array([1]), array([1]), array([3]), array([1]), array([3]), array([1]), array([1]), array([3]), array([1]), array([3]), array([1]), array([3]), array([1])]
# Rewards: [array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([0.], dtype=float32), array([1.], dtype=float32)]
# Episode 19 - Total Reward: [0.]
# Episode 20 - Total Reward: [0.]
# Episode 21 - Total Reward: [0.]
# Episode 22 - Total Reward: [0.]
# Episode 23 - Total Reward: [0.]
# Episode 24 - Total Reward: [0.]
# Episode 25 - Total Reward: [0.]
# Episode 26 - Total Reward: [0.]
# Episode 27 - Total Reward: [0.]
# Episode 28 - Total Reward: [0.]
# Episode 29 - Total Reward: [0.]
# Episode 30 - Total Reward: [0.]
# Episode 31 - Total Reward: [0.]
# Episode 32 - Total Reward: [0.]
# Episode 33 - Total Reward: [0.]
# Episode 34 - Total Reward: [0.]
# Episode 35 - Total Reward: [0.]
# Episode 36 - Total Reward: [0.]
# Episode 37 - Total Reward: [0.]
# Episode 38 - Total Reward: [0.]
# Episode 39 - Total Reward: [0.]
# Episode 40 - Total Reward: [0.]
# Episode 41 - Total Reward: [0.]
# Episode 42 - Total Reward: [0.]
# Episode 43 - Total Reward: [0.]
# Episode 44 - Total Reward: [0.]
# Episode 45 - Total Reward: [0.]
# Episode 46 - Total Reward: [0.]
# Episode 47 - Total Reward: [0.]
# Episode 48 - Total Reward: [0.]
# Episode 49 - Total Reward: [0.]
# Episode 50 - Total Reward: [0.]
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import gym
from stable_baselines3 import PPO
from stable_baselines3.common.vec_env import DummyVecEnv
from level2 import CustomFrozenLakeEnv

environment_name = 'FrozenLake-v1'
render_mode = 'human'

try:
    gym_env = gym.make(environment_name, desc=['SFFFHFFF', 'FHFFFFFF', 'FFFFFFFF', 'FFFFHFFF', 'FFFFFFFF', 'FFHFFHFF', 'FFFFFHFF', 'HHFFFFFG'], render_mode=render_mode)
    vec_env = DummyVecEnv([lambda: gym_env])
except gym.error.UnregisteredEnv:
    # If the Gymnasium environment is not available, use the OpenAI Gym environment
    vec_env = DummyVecEnv([lambda: gym.make(environment_name, desc=custom_lake, render_mode=render_mode)])


location = "/Users/software/Desktop/reinforcement_learning_practise/hackathon/level2_custom_frozenlake_model.zip"


# Load the trained model
model = PPO.load(location)

# Set the number of episodes for the trial
num_episodes = 50

# Run a trial of various episodes
for episode in range(num_episodes):
    obs = vec_env.reset()
    total_reward = 0
    done = False
    episode_path = {"observations": [], "actions": [], "rewards": []}

    while not done:
        action, _states = model.predict(obs, deterministic=True)
        obs, reward, done, info = vec_env.step(action)

        # Store observations, actions, and rewards during the episode
        episode_path["observations"].append(obs.copy())
        episode_path["actions"].append(action)
        episode_path["rewards"].append(reward)

        total_reward += reward

    print(f"Episode {episode + 1} - Total Reward: {total_reward}")

    # Check if the episode was successful
    if total_reward == 1:
        print("Episode succeeded!")
        print("Observations:", episode_path["observations"])
        print("Actions:", episode_path["actions"])
        print("Rewards:", episode_path["rewards"])

# Close the environment
vec_env.close()
# Out:
# /Users/software/anaconda3/envs/mlp/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Episode 1 - Total Reward: [0.]
# Episode 2 - Total Reward: [0.]
# Episode 3 - Total Reward: [0.]
# Episode 4 - Total Reward: [0.]
# Episode 5 - Total Reward: [0.]
# Episode 6 - Total Reward: [0.]
# Episode 7 - Total Reward: [0.]
# Episode 8 - Total Reward: [0.]
# Episode 9 - Total Reward: [0.]
# Episode 10 - Total Reward: [0.]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 35
#      33 while not done:
#      34     action, _states = model.predict(obs, deterministic=True)
# ---> 35     obs, reward, done, info = vec_env.step(action)
#      37     # Store observations, actions, and rewards during the episode
#      38     episode_path["observations"].append(obs.copy())
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/shimmy/openai_gym_compatibility.py:117, in GymV26CompatibilityV0.step(self, action)
#     108 def step(self, action: ActType) -> tuple[ObsType, float, bool, bool, dict]:
#     109     """Steps through the environment.
#     110
#     111     Args:
#    (...)
#     115         (observation, reward, terminated, truncated, info)
#     116     """
# --> 117     return self.gym_env.step(action)
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/gym/wrappers/time_limit.py:50, in TimeLimit.step(self, action)
#      39 def step(self, action):
#      40     """Steps through the environment and if the number of steps elapsed exceeds ``max_episode_steps`` then truncate.
#      41
#      42     Args:
#    (...)
#      48
#      49     """
# ---> 50     observation, reward, terminated, truncated, info = self.env.step(action)
#      51     self._elapsed_steps += 1
#      53     if self._elapsed_steps >= self._max_episode_steps:
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/gym/envs/toy_text/frozen_lake.py:252, in FrozenLakeEnv.step(self, a)
#     249 self.lastaction = a
#     251 if self.render_mode == "human":
# --> 252     self.render()
#     253 return (int(s), r, t, False, {"prob": p})
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/gym/envs/toy_text/frozen_lake.py:279, in FrozenLakeEnv.render(self)
#     277     return self._render_text()
#     278 else:  # self.render_mode in {"human", "rgb_array"}:
# --> 279     return self._render_gui(self.render_mode)
#
# File ~/anaconda3/envs/mlp/lib/python3.8/site-packages/gym/envs/toy_text/frozen_lake.py:373, in FrozenLakeEnv._render_gui(self, mode)
#     371     pygame.event.pump()
#     372     pygame.display.update()
# --> 373     self.clock.tick(self.metadata["render_fps"])
#     374 elif mode == "rgb_array":
#     375     return np.transpose(
#     376         np.array(pygame.surfarray.pixels3d(self.window_surface)), axes=(1, 0, 2)
#     377     )
#
# KeyboardInterrupt:
